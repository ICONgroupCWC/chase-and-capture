# %% [markdown]
# <h1>Mode 30</h1>

# %%
import json
from matplotlib import pyplot as plt
import pandas as pd

# %%
windowSize = 5
RuleBased1010 = '/Users/athmajanvivekananthan/WCE/JEPA - MARL/multi-agent/PPO/bert_marl/mode30-dqn/bertsekas-marl/results_experiment_rule_based.json'
RuleBased2020 = '/Users/athmajanvivekananthan/WCE/JEPA - MARL/multi-agent/PPO/bert_marl/mode30-dqn/bertsekas-marl/rule_based_2020.json'

SeqRand1010 = '/Users/athmajanvivekananthan/WCE/JEPA - MARL/multi-agent/PPO/bert_marl/mode30-dqn/bertsekas-marl/sequential_rollout_RAND.json'

Sequential1010 = '/Users/athmajanvivekananthan/WCE/JEPA - MARL/multi-agent/PPO/bert_marl/mode30-dqn/bertsekas-marl/sequential_rollout_1010.json'
Sequential2020 = '/Users/athmajanvivekananthan/WCE/JEPA - MARL/multi-agent/PPO/bert_marl/mode30-dqn/bertsekas-marl/sequential_rollout_2020.json'
approxSeq = '/Users/athmajanvivekananthan/WCE/JEPA - MARL/multi-agent/PPO/bert_marl/mode30-dqn/bertsekas-marl/approx_sequential_rollout_3410_57.json'
approxSeq2 = '/Users/athmajanvivekananthan/WCE/JEPA - MARL/multi-agent/PPO/bert_marl/mode30-dqn/bertsekas-marl/approx_sequential_rollout_7960_68.json'
approxSeq3 = '/Users/athmajanvivekananthan/WCE/JEPA - MARL/multi-agent/PPO/bert_marl/mode30-dqn/bertsekas-marl/approx_sequential_rollout_7960_68_200SIM.json'
cross_20 = '/Users/athmajanvivekananthan/WCE/JEPA - MARL/multi-agent/PPO/bert_marl/mode30-dqn/bertsekas-marl/approx_cross_rollout_9990_mode20.json'
cross_60 = '/Users/athmajanvivekananthan/WCE/JEPA - MARL/multi-agent/PPO/bert_marl/mode30-dqn/bertsekas-marl/approx_cross_rollout_4850_mode60.json'
cross_15 = '/Users/athmajanvivekananthan/WCE/JEPA - MARL/multi-agent/PPO/bert_marl/mode30-dqn/bertsekas-marl/approx_cross_rollout_1450_mode15.json'

SeqAdversary2020_1 = '/Users/athmajanvivekananthan/WCE/JEPA - MARL/multi-agent/PPO/bert_marl/mode30-dqn/bertsekas-marl/sequential_adversary_op_2020.json'


def findMovingAvg(inputDF,window):
    movingAvgList = []
    for i in range(inputDF.shape[0] - window):
        newDF = inputDF.loc[i:i + window]
        epi = inputDF.iloc[i]['episode']
        meanVal = newDF['steps'].mean()
        movingAvgList.append({'episode':epi, 'smoothed_steps':meanVal})
    dfMovingAvg = pd.DataFrame(movingAvgList)
    return dfMovingAvg

# %% [markdown]
# <h3>Load rule based plot</h3>

# %%
with open(RuleBased1010, 'r') as file:
        data = json.load(file)
listOfWholeTraining = []
epochs = list(data.keys())

i = 0
for trainEpoch in epochs:
    epochData = data[str(trainEpoch)]
    for indData in epochData:
        steps = indData['StepsToSolve']
        listOfWholeTraining.append({"episode": i, "steps": steps})
        i += 1

dfBasePolicy1010 = findMovingAvg(pd.DataFrame(listOfWholeTraining), windowSize)

with open(RuleBased2020, 'r') as file:
        data = json.load(file)
listOfWholeTraining = []
epochs = list(data.keys())

i = 0
for trainEpoch in epochs:
    epochData = data[str(trainEpoch)]
    for indData in epochData:
        steps = indData['StepsToSolve']
        listOfWholeTraining.append({"episode": i, "steps": steps})
        i += 1

dfBasePolicy2020 = findMovingAvg(pd.DataFrame(listOfWholeTraining), windowSize)

# %% [markdown]
# <h3>Load Sequential Rollout  plot</h3>

# %%
with open(Sequential1010, 'r') as file:
        data = json.load(file)
listOfWholeTraining = []
epochs = list(data.keys())

i = 0
for trainEpoch in epochs:
    epochData = data[str(trainEpoch)]
    for indData in epochData:
        steps = indData['StepsToSolve']
        listOfWholeTraining.append({"episode": i, "steps": steps})
        i += 1

dfSeq_noavg = pd.DataFrame(listOfWholeTraining)
dfSeqRollout1010 = findMovingAvg(pd.DataFrame(listOfWholeTraining), windowSize)


with open(Sequential2020, 'r') as file:
        data = json.load(file)
listOfWholeTraining = []
epochs = list(data.keys())

i = 0
for trainEpoch in epochs:
    epochData = data[str(trainEpoch)]
    for indData in epochData:
        steps = indData['StepsToSolve']
        listOfWholeTraining.append({"episode": i, "steps": steps})
        i += 1

dfSequential2020 = findMovingAvg(pd.DataFrame(listOfWholeTraining), windowSize)





with open(SeqRand1010, 'r') as file:
        data = json.load(file)
listOfWholeTraining = []
epochs = list(data.keys())

i = 0
for trainEpoch in epochs:
    epochData = data[str(trainEpoch)]
    for indData in epochData:
        steps = indData['StepsToSolve']
        listOfWholeTraining.append({"episode": i, "steps": steps})
        i += 1

dfSeqRAND1010 = findMovingAvg(pd.DataFrame(listOfWholeTraining), windowSize)

# %%
dfSeq_noavg.head()
# Out:
#    episode  steps
# 0        0      8
# 1        1      9
# 2        2     11
# 3        3      6
# 4        4     12

# %%
with open(SeqAdversary2020_1, 'r') as file:
        data = json.load(file)
listOfWholeTraining = []
epochs = list(data.keys())

i = 0
for trainEpoch in epochs:
    epochData = data[str(trainEpoch)]
    for indData in epochData:
        steps = indData['StepsToSolve']
        listOfWholeTraining.append({"episode": i, "steps": steps})
        i += 1

dfSeqAdversary2020_1 = findMovingAvg(pd.DataFrame(listOfWholeTraining), windowSize)

# %% [markdown]
# <h3>Load Approximated Sequential Rollout  plot</h3>

# %%
with open(approxSeq, 'r') as file:
        data = json.load(file)
listOfWholeTraining = []
epochs = list(data.keys())

i = 0
for trainEpoch in epochs:
    epochData = data[str(trainEpoch)]
    for indData in epochData:
        steps = indData['StepsToSolve']
        listOfWholeTraining.append({"episode": i, "steps": steps})
        i += 1

dfapproxSeq = findMovingAvg(pd.DataFrame(listOfWholeTraining), windowSize)


with open(approxSeq2, 'r') as file:
        data = json.load(file)
listOfWholeTraining = []
epochs = list(data.keys())

i = 0
for trainEpoch in epochs:
    epochData = data[str(trainEpoch)]
    for indData in epochData:
        steps = indData['StepsToSolve']
        listOfWholeTraining.append({"episode": i, "steps": steps})
        i += 1
dfModel_noavg = pd.DataFrame(listOfWholeTraining)
dfapproxSeq2 = findMovingAvg(pd.DataFrame(listOfWholeTraining), windowSize)


with open(approxSeq3, 'r') as file:
        data = json.load(file)
listOfWholeTraining = []
epochs = list(data.keys())

i = 0
for trainEpoch in epochs:
    epochData = data[str(trainEpoch)]
    for indData in epochData:
        steps = indData['StepsToSolve']
        listOfWholeTraining.append({"episode": i, "steps": steps})
        i += 1
dfapproxSeq3_noavg = pd.DataFrame(listOfWholeTraining)
dfapproxSeq3 = findMovingAvg(dfapproxSeq3_noavg, windowSize)

# %%
dfModel_noavg.hist(bins=10)
# Out:
# array([[<Axes: title={'center': 'episode'}>,
#         <Axes: title={'center': 'steps'}>]], dtype=object)

# %%
dfSeq_noavg.hist(bins=10)
# Out:
# array([[<Axes: title={'center': 'episode'}>,
#         <Axes: title={'center': 'steps'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
import numpy as np


dfSeq_noavg = dfSeq_noavg.iloc[0:1500]
dfSeq_noavg.shape

# Get the overall min and max values across both dataframes
min_value = min(dfModel_noavg.min().min(), dfSeq_noavg.min().min())
max_value = max(dfModel_noavg.max().max(), dfSeq_noavg.max().max())

# Define bin edges with a fixed number of bins (10 in this case)
bin_edges = np.linspace(0, 30, 50)  # 10 bins

# Plot histograms with the same bin edges
dfModel_noavg.hist(bins=bin_edges)
dfSeq_noavg.hist(bins=bin_edges)

# Show the plots
plt.show()

# %%
dfModel_noavg.shape
# Out:
# (3750, 2)

# %%
import matplotlib.pyplot as plt
import numpy as np

dfSeq_noavg = dfSeq_noavg.iloc[0:1500]

# Get the overall min and max values across both dataframes
min_value = min(dfModel_noavg.min().min(), dfSeq_noavg.min().min())
max_value = max(dfModel_noavg.max().max(), dfSeq_noavg.max().max())

# Define bin edges with a fixed number of bins (you defined 50 in this case)
bin_edges = np.linspace(0, 30, 50)

# Plot both histograms on the same graph
plt.hist(dfModel_noavg.values.flatten(), bins=bin_edges, alpha=0.5, label='Model Data', color='blue')
plt.hist(dfSeq_noavg.values.flatten(), bins=bin_edges, alpha=0.5, label='Seq Data', color='orange')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Model and Seq Data')

# Add a legend
plt.legend()

# Show the plot
plt.show()
print(dfSeq_noavg.shape)
print(dfModel_noavg.shape)
# Out:
# (150, 2)
# (3750, 2)

# %% [markdown]
# <h3>Load Cross Async Auto Trained on mode 20 MSE deployed on Mode 30 plot</h3>

# %%
with open(cross_20, 'r') as file:
        data = json.load(file)
listOfWholeTraining = []
epochs = list(data.keys())

i = 0
for trainEpoch in epochs:
    epochData = data[str(trainEpoch)]
    for indData in epochData:
        steps = indData['StepsToSolve']
        listOfWholeTraining.append({"episode": i, "steps": steps})
        i += 1

dfcross_20 = findMovingAvg(pd.DataFrame(listOfWholeTraining), windowSize)

# %% [markdown]
# <h3>Load Cross Async Auto Trained on mode 60 MSE deployed on Mode 30 plot</h3>

# %%
with open(cross_60, 'r') as file:
        data = json.load(file)
listOfWholeTraining = []
epochs = list(data.keys())

i = 0
for trainEpoch in epochs:
    epochData = data[str(trainEpoch)]
    for indData in epochData:
        steps = indData['StepsToSolve']
        listOfWholeTraining.append({"episode": i, "steps": steps})
        i += 1

dfcross_60 = findMovingAvg(pd.DataFrame(listOfWholeTraining), windowSize)

# %%
with open(cross_15, 'r') as file:
        data = json.load(file)
listOfWholeTraining = []
epochs = list(data.keys())

i = 0
for trainEpoch in epochs:
    epochData = data[str(trainEpoch)]
    for indData in epochData:
        steps = indData['StepsToSolve']
        listOfWholeTraining.append({"episode": i, "steps": steps})
        i += 1

dfcross_15 = findMovingAvg(pd.DataFrame(listOfWholeTraining), windowSize)

# %% [markdown]
# <h2>Plots</h2>

# %%
plt.figure(figsize=(15, 8))

plt.plot(dfBasePolicy1010['episode'], dfBasePolicy1010['smoothed_steps'], label='Base 1010', color='blue', linestyle='-')
#plt.plot(dfBasePolicy2020['episode'], dfBasePolicy2020['smoothed_steps'], label='Base 2020', color='blue', linestyle='-')
plt.plot(dfSeqRollout['episode'], dfSeqRollout['smoothed_steps'], label='Seq Rollout', color='red', linestyle='-')
#plt.plot(dfSequential2020['episode'], dfSequential2020['smoothed_steps'], label='Seq 2020', color='red', linestyle='-')
#plt.plot(dfSeqRAND1010['episode'], dfSeqRAND1010['smoothed_steps'], label='Seq RAND 1010', color='orange', linestyle='-')
#plt.plot(dfSeqAdversary2020_1['episode'], dfSeqAdversary2020_1['smoothed_steps'], label='Seq Adversary 2020', color='magenta', linestyle='-')


#plt.plot(dfcross_20['episode'], dfcross_20['smoothed_steps'], label='Cross Mode from 20', color='yellow', linestyle='-')
#plt.plot(dfcross_60['episode'], dfcross_60['smoothed_steps'], label='Cross Mode from 60', color='orange', linestyle='-')
plt.plot(dfcross_15['episode'], dfcross_15['smoothed_steps'], label='Cross Mode from 15', color='orange', linestyle='--')
#plt.plot(dfapproxSeq['episode'], dfapproxSeq['smoothed_steps'], label='Approx Seq 1', color='green', linestyle='-')
plt.plot(dfapproxSeq3['episode'], dfapproxSeq3['smoothed_steps'], label='Approx Seq 68%', color='green', linestyle='--')
plt.legend()

# %%
dfcross_15.mean()
# Out:
# episode           724.500000
# smoothed_steps     14.810913
# dtype: float64

# %%
dfapproxSeq2.mean()
# Out:
# episode           1849.500000
# smoothed_steps      14.076433
# dtype: float64

# %% [markdown]
# <h1> Adaptation Graphs</h1>

# %%
dfMode30BL = pd.read_csv('/Users/athmajanvivekananthan/WCE/JEPA - MARL/multi-agent/PPO/bert_marl/mode30-dqn/bertsekas-marl/Mode30_baselines.csv')

# %%
dfMode30_BasePolicy = dfMode30BL[["base policy - steps_to_solve","Step"]].copy()
dfMode30_ApprxSeq = dfMode30BL[["Approx Sig Sequential - steps_to_solve","Step"]].copy()
dfMode30_Seq = dfMode30BL[["Sequential - steps_to_solve","Step"]].copy()

# %%
import pandas as pd

# Assuming dfMode30_BasePolicy, dfMode30_ApprxSeq, dfMode30_Seq have 300 rows

# Calculate rolling mean and std for Base Policy with window size of 3
dfMode30_BasePolicy['base_policy_mean'] = dfMode30_BasePolicy['base policy - steps_to_solve'].rolling(window=30).mean()
dfMode30_BasePolicy['base_policy_std'] = dfMode30_BasePolicy['base policy - steps_to_solve'].rolling(window=30).std()

# Calculate rolling mean and std for Approx Sequential with window size of 3
dfMode30_ApprxSeq['approx_seq_mean'] = dfMode30_ApprxSeq['Approx Sig Sequential - steps_to_solve'].rolling(window=30).mean()
dfMode30_ApprxSeq['approx_seq_std'] = dfMode30_ApprxSeq['Approx Sig Sequential - steps_to_solve'].rolling(window=30).std()

# Calculate rolling mean and std for Sequential with window size of 3
dfMode30_Seq['seq_mean'] = dfMode30_Seq['Sequential - steps_to_solve'].rolling(window=30).mean()
dfMode30_Seq['seq_std'] = dfMode30_Seq['Sequential - steps_to_solve'].rolling(window=30).std()

# Drop the first two rows since rolling mean/std for window=3 will be NaN
dfMode30_BasePolicy = dfMode30_BasePolicy.dropna().reset_index(drop=True)
dfMode30_ApprxSeq = dfMode30_ApprxSeq.dropna().reset_index(drop=True)
dfMode30_Seq = dfMode30_Seq.dropna().reset_index(drop=True)

# Sampling every 3rd row to reduce from 300 rows to 100 rows
dfMode30_BasePolicy_grouped = dfMode30_BasePolicy[['base_policy_mean', 'base_policy_std']].iloc[::3].reset_index(drop=True)
dfMode30_ApprxSeq_grouped = dfMode30_ApprxSeq[['approx_seq_mean', 'approx_seq_std']].iloc[::3].reset_index(drop=True)
dfMode30_Seq_grouped = dfMode30_Seq[['seq_mean', 'seq_std']].iloc[::3].reset_index(drop=True)

# Renaming columns for consistency
dfMode30_BasePolicy_grouped = dfMode30_BasePolicy_grouped.rename(columns={'base_policy_mean': 'mean', 'base_policy_std': 'std'})
dfMode30_ApprxSeq_grouped = dfMode30_ApprxSeq_grouped.rename(columns={'approx_seq_mean': 'mean', 'approx_seq_std': 'std'})
dfMode30_Seq_grouped = dfMode30_Seq_grouped.rename(columns={'seq_mean': 'mean', 'seq_std': 'std'})

# Now you have 100 rows for each DataFrame with rolling mean and std

# %%
bPEpochs = list(range(dfMode30_BasePolicy_grouped.shape[0]))
bpMean = dfMode30_BasePolicy_grouped["mean"].to_list()
bpstd = dfMode30_BasePolicy_grouped["std"].to_list()
sqRollEpochs = list(range(dfMode30_Seq_grouped.shape[0]))
sqRollMean = dfMode30_Seq_grouped["mean"].to_list()
sqRollstd = dfMode30_Seq_grouped["std"].to_list()
ApproxSeqRollEpochs = list(range(dfMode30_ApprxSeq_grouped.shape[0]))
ApproxSeqRollMean = dfMode30_ApprxSeq_grouped["mean"].to_list()
ApproxSeqRollstd = dfMode30_ApprxSeq_grouped["std"].to_list()

bpColour = 'blue'
sqRollColour = 'red'
seqRandSigColour = 'cyan'
ApproxSeqRollColour = 'green'

# %%
def plot_with_shading(epochs, mean_values, std_values, color, label):
    """Function to plot mean with shaded standard deviation."""
    plt.plot(epochs, mean_values, color=color, label=label, linewidth=2)
    plt.fill_between(epochs, 
                     np.array(mean_values) - np.array(std_values), 
                     np.array(mean_values) + np.array(std_values), 
                     color=color, alpha=0.1, label=None)

epochs = [int(epoch) for epoch in bPEpochs]  # Ensure epochs are integers

plt.figure(figsize=(10, 6))

plot_with_shading(bPEpochs, bpMean, bpstd, bpColour, label='Base Policy')
plot_with_shading(sqRollEpochs, sqRollMean, sqRollstd, sqRollColour, label='Sequential Rollout - Uncertainty 1')
#plot_with_shading(seqRandSigEpochs, seqRandSigMean, seqRandSigstd, seqRandSigColour, label='Sequential RandSig')
plot_with_shading(ApproxSeqRollEpochs, ApproxSeqRollMean, ApproxSeqRollstd, ApproxSeqRollColour, label='Autonomous Rollout - Uncertainty 1')

## Cross Implementations
#plot_with_shading(cross30Epochs, cross30Mean, cross30std, cross30Colour, label='Autonomous Agent from Uncertainty 2')
#plot_with_shading(cross30_BMEpochs, cross30_BMMean, cross30_BMstd, cross30_BMColour, label='Autonomous Agent from Uncertainty 2 BM')
#plot_with_shading(cross30_epochs_total, cross30_mean_total, cross30_std_total, cross30_Total_Colour, label='adaptation')





# Customize the plot
plt.title('Mean and Standard Deviation of Steps to Solve Over Epochs')
plt.xlabel('Iterations')
plt.ylabel('Steps to Solve')
plt.legend()
plt.grid(True)
#plt.ylim(12, 21)
plt.xlim(0, 99)

plt.xticks(np.arange(min(epochs), max(epochs) + 1, 10))

plt.tight_layout()
plt.show()
